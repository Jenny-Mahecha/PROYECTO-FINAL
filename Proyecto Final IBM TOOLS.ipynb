# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio#

# %% [markdown]
# **JENNY MAHECHA CHACON**

# %% [markdown]
# *La ciencia de datos siempre me ha llamado la atención*, *es una ciencia muy interesante*

# %% [markdown]
# <h3>Sumatoria de dos numeros</h3>

# %%
3*8
# Out:
# 24

# %% [markdown]
# * Analisis  -Graficos
# * Formulas
# *  Herramientas
#   1. Base de datos
#   2. Wastson studio
#   3. SPSS
#
#   ***

# %% [markdown]
# ![LOGO](data:image/jpeg;base64,...)
